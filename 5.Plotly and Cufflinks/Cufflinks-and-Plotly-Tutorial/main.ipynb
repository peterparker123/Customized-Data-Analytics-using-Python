# %%
#importing modules
import plotly
import cufflinks as cf
cf.go_offline()  #This lets us make our plots offline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Collecting Data

# %%
#Most of the data collected was via web scraping and from the Nigeria Bureau of Statistics

# %%
Data0 = pd.read_csv("Consumption.csv") #Data on Nigeria electricity consumption (1971-2014)
Data1 = pd.read_csv("Jamb_no_of_applicants(2017-2018)") #jamb 2017-2018 data
Data2 = pd.read_csv("DANGCEM STOCK(March-July)") #Dangote cement stock from march to july

# %% [markdown]
# ## Line Plots

# %% [markdown]
# #### DANGCEM line plot

# %%
Data2.iplot(x="Date",y=["Open","High","Low","Change","Price"],title="DANGOTE CEMENT STOCK(MAR-APR)",
            theme="solar")
# Out:
# <div>                            <div id="b48c7916-3f4b-4ce5-81c6-fac4263da898" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ### JAMB Data Line plot

# %%
Data1.iloc[0:37,:].iplot(x="State",y=["Female_2017","Male_2017"],theme='henanigans',
                         title="JAMB APPLICANTS STATISTICS BY STATE AND GENDER FOR 2017")
# Out:
# <div>                            <div id="93238349-3911-4a51-a248-026d8b0e6bb8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Data1.iloc[0:37,:].iplot(x="State",y=["Females_2018","Males_2018"],
                         theme='henanigans',title="JAMB APPLICANTS STATISTICS BY STATE AND GENDER FOR 2018")
# Out:
# <div>                            <div id="e30cd740-729a-49fa-8c7d-f32caf92ea11" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Data1.iloc[0:37,:].iplot(x="State",y=["Female_2017","Females_2018","Male_2017","Males_2018"],
                         theme='polar',title="JAMB APPLICANTS STATISTICS BY STATE AND GENDER FOR 2018")
# Out:
# <div>                            <div id="9c92cfd3-e066-4fd6-a96c-bf96b9704ec3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# #### Nigeria Electricity comsumtion line plot

# %%
Data0.iplot(x="Year",y="Value(Kwh)",theme='pearl',
            title="Nigeria Electricity Consumption(Kwh) 1971-2014",yTitle="Value(kwh)",xTitle="Year")
# Out:
# <div>                            <div id="c862e3a4-1446-4163-bb97-37b81fac39cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
cf.getThemes() #You could use these other themes too :) ...
#you could set a default theme using the syntax cf.set_config_file(theme='pearl')
# Out:
# ['ggplot', 'pearl', 'solar', 'space', 'white', 'polar', 'henanigans']

# %% [markdown]
# ### Bar Plots

# %% [markdown]
# ### Jamb Data Bar plot

# %%
Data1.iloc[0:37,:].iplot(kind="bar",x="State",y=["Female_2017"],theme='polar',
                         title="JAMB APPLICANTS STATISTICS BY STATE AND GENDER FOR FEMALES 2017")
# Out:
# <div>                            <div id="f4aae217-f272-4d0b-9abb-15c0f66d9d17" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Data1.iloc[0:37,:].iplot(kind="bar",x="State",y=["Male_2017","Female_2017"],theme='polar',
                         title="JAMB APPLICANTS STATISTICS BY STATE AND GENDER FOR 2017")
# Out:
# <div>                            <div id="8b3b252b-2939-4c1f-b57f-801d6d1b16a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Data1.iloc[0:37,:].iplot(kind="bar",x="State",y=["Females_2018","Males_2018"],theme='polar',
                         title="JAMB APPLICANTS STATISTICS BY STATE AND GENDER FOR 2018")
# Out:
# <div>                            <div id="0efcb7f4-e4f7-41c3-8ba3-7fc300e4701e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
#You can change the orientation by using the orientation = "h" or "v" syntax
Data1.iloc[0:37,:].iplot(kind="bar",x="State",y=["Females_2018","Males_2018"],theme='polar',
                         title="JAMB APPLICANTS STATISTICS BY STATE AND GENDER FOR 2018",orientation='h')
# Out:
# <div>                            <div id="80b25b57-541a-4c1f-9c20-f4f5323a2299" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Data1.iloc[0:37,:].iplot(kind="bar",x="State",y=["Male_2017","Female_2017","Females_2018","Males_2018"],theme='space',
                         title="JAMB APPLICANTS STATISTICS BY STATE AND GENDER FROM 2017-2018")
#This plot doesnt look good for presentation, instread we could do something...
# Out:
# <div>                            <div id="ac585abc-3c6a-46ed-a0fd-b6db58728023" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
#You could plot a group bar chart instead by setting barmode= "stack"
Data1.iloc[0:37,:].iplot(kind="bar",barmode="stack",x="State",y=["Male_2017","Female_2017","Females_2018","Males_2018"],theme='space',
                         title="JAMB APPLICANTS STATISTICS BY STATE AND GENDER FROM 2017-2018")
#This plot carries every details about the applicants and year
#by double clicking on one of the legends youll see the individual plots.
# Out:
# <div>
#
#
#             <div id="5e0c8f56-7ce1-4941-8cd8-10d8e48013f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5e0c8f56-7ce1-4941-8cd8-10d8e48013f3")) {
#                     Plotly.newPlot(
#                         '5e0c8f56-7ce1-4941-8cd8-10d8e48013f3',
# ...

# %% [markdown]
# ## Box Plots

# %%
Data0['Value(Kwh)'].iplot(kind="box",
                          title="Details about energy consumption(1971-2014)")
# Out:
# <div>                            <div id="09d59b26-95b8-4169-855b-24e02378130a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Data1.head()
# Out:
#    S/N                 State  Female_2017  Male_2017  Total_2017  \
# 0  1.0  ABIA                      27351.0    24299.0     51650.0
# 1  2.0  ADAMAWA                    9187.0    14056.0     23243.0
# 2  3.0  AKWA IBOM                 32081.0    30260.0     62341.0
# 3  4.0  ANAMBRA                   42764.0    34688.0     77452.0
# 4  5.0  BAUCHI                     6681.0    18427.0     25108.0
#
#    Females_2018  Males_2018  Total_2018
# 0       25487.0     22361.0     47848.0
# 1        8636.0     13587.0     22223.0
# 2       30120.0     27737.0     57857.0
# 3       40242.0     32629.0     72871.0
# 4        6615.0     18287.0     24902.0

# %%
Data1[["Females_2018","Males_2018","Male_2017","Female_2017"]].iplot(kind="box",
                          title="Details about Jamb Applicants based on gender",theme="polar")
# Out:
# <div>                            <div id="844f439c-2837-4da4-8ee4-e507f05741be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Data2[["Price","Open","Low","High"]].iplot(kind="box",
                          title="Details about DANGCEM Stock (Mar-July)",theme="polar")
# Out:
# <div>                            <div id="cb569ceb-8755-416a-919a-feab84aa739f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ### some other cool plots could could try out are the Scatter plot, Area plot,Bubble Chart etc.

# %% [markdown]
# ## Hosting Plots

# %%
#We are going to host this particular plot to our plotly account
Data1.iloc[0:37,:].iplot(kind="bar",barmode="stack",x="State",y=["Male_2017","Female_2017","Females_2018","Males_2018"],theme='space',
                         title="JAMB APPLICANTS STATISTICS BY STATE AND GENDER FROM 2017-2018")
#Click on the "Export to plot.ly"
# Out:
# <div>                            <div id="66b0456d-6f4e-45c0-ae92-d9719b29140e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# It will take you to this page...
# <br />
#
# !["Pic1"](pic1.jpg)

# %% [markdown]
# ##### Click on save

# %% [markdown]
# It will take you to this page...
# !["Pic2"](Annotation.jpg)

# %% [markdown]
# You could change the plot to public or private and Grid(your_data) to private or public, it depends on what your working on, in my own case I made the plot public and grid public also. After that, click on Save

# %% [markdown]
# You'll see a share button, then a page like this will pop-up
# !["Pic3"](Pic3.jpg)

# %% [markdown]
# Plotly has successfully hosted your plot. you can paste that link(https://plot.ly/~aminuisrael/21) in your browser and you'll see your plots, your data, your codes, and you can set the plot to full screen for presentation purposes

# %% [markdown]
# # Thank you!!!
